# %% [markdown]
# Link: http://rosalind.info/problems/revc/

# %%
dna ='...'

# %%
reverse = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}
complement = ''
for base in dna:
    complement += reverse[base]
complement[::-1]
# Out:
# '...'

# %%
complement[::-1]
# Out:
# '...'
